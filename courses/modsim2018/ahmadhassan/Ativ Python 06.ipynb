# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import math

# %%
t = np.arange(0,10,0.1)
v = 30
a = 30
g = -9,81

# %%
Vy = v*(1/2)
Vx = v*(0.86602)
print (Vy)
print (Vx)
# Out:
# 15.0
# 25.9806

# %%
sy = 15*t - 4.905*t**2
sx = 25.9806*t

plt.plot(sx,sy)
plt.show()
