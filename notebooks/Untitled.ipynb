# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
m = 2
g = 9.81
k1 = 1e4
k2 = 1e6

# %%
x0 = 0.01
v0 = 4

# %%
dt = 0.00001
t = np.arange(0,0.01,dt)

A = x0 + m*g*(k1+k2)/(k1*k2)
B = v0*m*(k1+k2)/(k1*k2)
omega = k1*k2/(m*(k1+k2))
print(1/(omega/2/np.pi))
plt.figure()
plt.plot(t,A*np.cos(omega*t)+B*np.sin(omega*t)-m*g*(k1+k2)/(k1*k2))
plt.plot(t,-A*omega*np.sin(omega*t)+B*omega*np.sin(omega*t))
plt.show()
# Out:
# 0.0012692034320502762
# <img src="data:image/png;base64,..." width="640">

# %%
x = x0
vx = v0

for

# %%
plt.figure()
plt.plot(0,np.log(2700),'.', 0.3, np.log(350),'.' )
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
plt.figure()
plt.plot(0,np.log(1400),'.', 0.05, np.log(600),'.' )
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
(5.8-7.9)/0.3
# Out:
# -7.000000000000002

# %%
(6.4-7.25)/0.05
# Out:
# -16.999999999999993

# %%
(36**2+(1.6*np.pi)**2)/4
# Out:
# 330.3165468166972

# %%
36**2
# Out:
# 1296

# %%
4*330
# Out:
# 1320

# %%
(-36/75-(1.6*np.pi)**2)*75/-4
# Out:
# 482.7410112522892

# %%
11*2*60
# Out:
# 1320

# %%
1320**2/4/60+1.6**2*np.pi**2/4*60
# Out:
# 7638.992809001831

# %%
3500*0.2/4
# Out:
# 175.0

# %%
from sympy import *
sym.init_printing()

# %%
lambd = symbols('lambda')
k1, k2, b = symbols('k_1, k_2, b')

# %%
lambd
# Out:
# λ

# %%
simplify(simplify(solve(lambd**3 +2.5e5/8000*lambd**2+(k1+2.5e5)/65*lambd+(k1+2.5e5)*2.5e5/8000-2.5**2*1e10/8000/65, lambd)))
# Out:
# ⎡
# ⎢
# ⎢                                              0.333333333333333⋅(-0.046153846
# ⎢- ───────────────────────────────────────────────────────────────────────────
# ⎢      _______________________________________________________________________
# ⎢     ╱
# ⎢  3 ╱                            ⎛
# ⎣  ╲╱   419.711538461538⋅k₁ + 0.5⋅⎝- 4.0⋅(-0.0461538461538462⋅k₁ - 10561.89903
#
#
#
# 1538462⋅k₁ - 10561.8990384615)
# ─────────────────────────────────────────────────────────────────────────── -
# ___________________________________________________________________________
#                                                     0.5
#       3                                           2⎞
# 84615)  + (839.423076923077⋅k₁ + 206671612.079327) ⎠    + 103335806.039663
#
#                       ________________________________________________________
#                      ╱
#                   3 ╱                            ⎛
# ...

# %%
expand_mul((lambd+19)*(lambd+9-4*pi*I)*(lambd+9+4*pi*I))
# Out:
#  3       2       2                         2
# λ  + 37⋅λ  + 16⋅π ⋅λ + 423⋅λ + 1539 + 304⋅π

# %%
(16*7*np.pi**2-112*np.pi**2)*65/70
# Out:
# 0.0

# %%
16*9
# Out:
# 144

# %%
(16*37*np.pi**2-1539-304*np.pi**2)*65/37/37
# Out:
# 61.88750503169671

# %%
60*37
# Out:
# 2220

# %%
65*16*np.pi**2-2220
# Out:
# 8044.3885771329315
